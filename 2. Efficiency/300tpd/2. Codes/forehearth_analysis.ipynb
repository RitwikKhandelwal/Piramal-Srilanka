# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("job_plan_30min_R.csv", encoding="ISO-8859–1")
# Out:
# C:\Users\Rishav\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0            StartTime              EndTime     Id  \
# 0                0  2020-09-17 18:30:00  2020-09-17 19:00:00  16372
# 1                1  2020-09-17 19:00:00  2020-09-17 19:30:00  16372
# 2                2  2020-09-17 19:30:00  2020-09-17 20:00:00  16372
# 3                3  2020-09-17 20:00:00  2020-09-17 20:30:00  16372
# 4                4  2020-09-17 20:30:00  2020-09-17 21:00:00  16372
# ...            ...                  ...                  ...    ...
# 196235      196235  2022-02-07 13:30:00  2022-02-07 14:00:00  25574
# 196236      196236  2022-02-07 14:00:00  2022-02-07 14:30:00  25574
# 196237      196237  2022-02-07 14:30:00  2022-02-07 15:00:00  25574
# 196238      196238  2022-02-07 15:00:00  2022-02-07 15:30:00  25574
# 196239      196239  2022-02-07 15:30:00  2022-02-07 16:00:00  25574
#
#                                   Identifier LineName  Number  \
# 0       7c794b6a-5b1f-4985-bdf6-df318e23348a       R1  J16372
# ...

# %%
df9_ = dict(df["FGCode"].value_counts()[:1])
li = [k for k,v in df9_.items()]
li
# Out:
# ['F3T1891QHLQ020001P']

# %%
df_ = df[df["FGCode"].isin(li)].reset_index()

# %%
df_["StartTime"]  = pd.to_datetime(df_["StartTime"])
df_["EndTime"] = pd.to_datetime(df_["EndTime"])

# %%
df_
# Out:
#        index  Unnamed: 0           StartTime             EndTime     Id  \
# 0      70517       70517 2021-01-01 02:30:00 2021-01-01 03:00:00  18206
# 1      70518       70518 2021-01-01 03:00:00 2021-01-01 03:30:00  18206
# 2      70519       70519 2021-01-01 03:30:00 2021-01-01 04:00:00  18206
# 3      70520       70520 2021-01-01 04:00:00 2021-01-01 04:30:00  18206
# 4      70521       70521 2021-01-01 04:30:00 2021-01-01 05:00:00  18206
# ...      ...         ...                 ...                 ...    ...
# 17058  87575       87575 2022-01-27 21:30:00 2022-01-27 22:00:00  24902
# 17059  87576       87576 2022-01-27 22:00:00 2022-01-27 22:30:00  24902
# 17060  87577       87577 2022-01-27 22:30:00 2022-01-27 23:00:00  24902
# 17061  87578       87578 2022-01-27 23:00:00 2022-01-27 23:30:00  24902
# 17062  87579       87579 2022-01-27 23:30:00 2022-01-28 00:00:00  24902
#
#                                  Identifier LineName  Number            Name  \
# ...

# %%
df2 = pd.read_csv(
    "Full_Flat_File_with_Defect_P3.csv", encoding="ISO-8859–1")
df2 = df2.drop("Unnamed: 0", axis=1)
df2
# Out:
#            Date  P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  \
# 0    14-12-2021        29.05            29.1    23.99    82.6       44
# 1    15-12-2021        30.40            30.4    27.31    89.8       32
# 2    16-12-2021        27.64            27.6    20.10    72.7       47
# 3    17-12-2021        26.18            26.2    19.55    74.7       48
# 4    18-12-2021        25.93            25.9    16.39    63.2       47
# ..          ...          ...             ...      ...     ...      ...
# 111  01-03-2022        32.37            32.2    27.09    84.2       52
# 112  02-03-2022        37.28            32.2    27.09    84.2       56
# 113  03-03-2022        36.63            32.2    27.09    84.2       57
# 114  04-03-2022        36.02            32.2    27.09    84.2       51
# 115  05-03-2022        33.85            32.2    27.09    84.2       46
#
#      Total Cullet %  Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
df2.head(20)
# Out:
#           Date  P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  \
# 0   14-12-2021        29.05            29.1    23.99    82.6       44
# 1   15-12-2021        30.40            30.4    27.31    89.8       32
# 2   16-12-2021        27.64            27.6    20.10    72.7       47
# 3   17-12-2021        26.18            26.2    19.55    74.7       48
# 4   18-12-2021        25.93            25.9    16.39    63.2       47
# 5   19-12-2021        26.52            26.5    16.31    61.5       45
# 6   20-12-2021        30.41            29.9    23.35    78.1       56
# 7   21-12-2021        31.14            31.1    27.44    88.1       54
# 8   22-12-2021        32.87            31.5    16.56    52.6       66
# 9   23-12-2021        33.92            33.9    21.11    62.2       44
# 10  24-12-2021        28.88            26.5    20.51    77.5       49
# 11  25-12-2021        28.57            28.3    24.11    85.3       45
# ...

# %%
# df2 = df2[df2["FGCode"] == "F2Z0312QHLQ030001X"]

# %%
df2
# Out:
#            Date  P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  \
# 0    14-12-2021        29.05            29.1    23.99    82.6       44
# 1    15-12-2021        30.40            30.4    27.31    89.8       32
# 2    16-12-2021        27.64            27.6    20.10    72.7       47
# 3    17-12-2021        26.18            26.2    19.55    74.7       48
# 4    18-12-2021        25.93            25.9    16.39    63.2       47
# ..          ...          ...             ...      ...     ...      ...
# 111  01-03-2022        32.37            32.2    27.09    84.2       52
# 112  02-03-2022        37.28            32.2    27.09    84.2       56
# 113  03-03-2022        36.63            32.2    27.09    84.2       57
# 114  04-03-2022        36.02            32.2    27.09    84.2       51
# 115  05-03-2022        33.85            32.2    27.09    84.2       46
#
#      Total Cullet %  Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
li = list(df2.columns)
li
# Out:
# ['Date',
#  'P3_sap_draw',
#  'P3_actual_draw',
#  'P3_pack',
#  'P3_eff',
#  'P3_seed',
#  'Total Cullet %',
#  'Melting cost-Rs/ton/Draw',
#  'Barrier Boosting (kWh)',
#  'Capacitive Boosting (kWh)',
#  'Boosting (kWh)',
#  'Barrier Boosting Per ton (kWh/ton)',
#  'Capacitive Boosting Per ton (kWh/ton)',
#  'FO-Furnace Consumption (MT)',
#  'FO-Furnace Consumption (kg per MT)',
#  'LPG -WE/FHs Consumption(kg)',
#  'Melting Energy -Kcal//Draw of glass',
#  'Bottom Front (oC)',
#  'Throat Riser (oC)',
#  'LPG WE & FH (Kg /Ton/ draw)',
#  'Boosting per ton (kWh/ton draw)',
#  'FO density (Specific Gravity)',
#  'FO consumption (Liters)',
#  'FO L/ton',
#  'Defect Insp Machine%',
#  'Defect Light Inspection%',
#  'Defect Hot End Reject%',
#  'Total Defect%',
#  'Glass CE-kg',
#  'Glass Packing-kg',
#  'FURNACE COMBUSTION AIR FLOW',
#  'FURNACE GAS FLOW',
#  'FURNACE GLASS LEVEL',
#  'FURNACE OIL FLOW',
#  'FURNACE PRESSURE',
#  'LINE P3 ZONE 02 TEMPERATURE',
# ...

# %%
# df2 = df2.drop("glass_properties_date", axis =1)
# df2 = df2.drop("Number", axis =1)
# df2 = df2.drop("FGCode", axis=1)
# df2= df2.drop("Name", axis =1)
df2 = df2.drop(df2.filter(regex="Unnamed"), axis=1)

# %%
df2
# Out:
#            Date  P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  \
# 0    14-12-2021        29.05            29.1    23.99    82.6       44
# 1    15-12-2021        30.40            30.4    27.31    89.8       32
# 2    16-12-2021        27.64            27.6    20.10    72.7       47
# 3    17-12-2021        26.18            26.2    19.55    74.7       48
# 4    18-12-2021        25.93            25.9    16.39    63.2       47
# ..          ...          ...             ...      ...     ...      ...
# 111  01-03-2022        32.37            32.2    27.09    84.2       52
# 112  02-03-2022        37.28            32.2    27.09    84.2       56
# 113  03-03-2022        36.63            32.2    27.09    84.2       57
# 114  04-03-2022        36.02            32.2    27.09    84.2       51
# 115  05-03-2022        33.85            32.2    27.09    84.2       46
#
#      Total Cullet %  Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
df2["Date"] = pd.to_datetime(df2["Date"])

# %%
# df2 = df2.drop("Classification", axis=1)
# df2 = df2.drop("ProductionOrderNumber", axis=1)
df2 = df2.drop("Date", axis=1)

# %%
df2
# Out:
#      P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  Total Cullet %  \
# 0          29.05            29.1    23.99    82.6       44              30
# 1          30.40            30.4    27.31    89.8       32              30
# 2          27.64            27.6    20.10    72.7       47              30
# 3          26.18            26.2    19.55    74.7       48              30
# 4          25.93            25.9    16.39    63.2       47              30
# ..           ...             ...      ...     ...      ...             ...
# 111        32.37            32.2    27.09    84.2       52              30
# 112        37.28            32.2    27.09    84.2       56              30
# 113        36.63            32.2    27.09    84.2       57              30
# 114        36.02            32.2    27.09    84.2       51              30
# 115        33.85            32.2    27.09    84.2       46              30
#
#      Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
# df2 = df2.dropna()
df2 = df2.reset_index()
df2 = df2.drop("index", axis=1)

# %%
df2 = df2.fillna(0)
df2
# Out:
#      P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  Total Cullet %  \
# 0          29.05            29.1    23.99    82.6       44              30
# 1          30.40            30.4    27.31    89.8       32              30
# 2          27.64            27.6    20.10    72.7       47              30
# 3          26.18            26.2    19.55    74.7       48              30
# 4          25.93            25.9    16.39    63.2       47              30
# ..           ...             ...      ...     ...      ...             ...
# 111        32.37            32.2    27.09    84.2       52              30
# 112        37.28            32.2    27.09    84.2       56              30
# 113        36.63            32.2    27.09    84.2       57              30
# 114        36.02            32.2    27.09    84.2       51              30
# 115        33.85            32.2    27.09    84.2       46              30
#
#      Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
# df2.to_csv("Forehearth_Analysis_Flat_File_32.000 OZ BSTN RD SHELF STK F.csv")
# #

# %%
import numpy as np

# %%
# Fibber Optic Thermometer -Distributer-zone -7_DB734,DD134,QC
# Fibber Optic Thermometer - Distributer-zone - 8_DB737, DD134, QC
# Fibber Optic Thermometer -Distributer-zone -6_DB731,DD134,QC
# Fiber Optic Thermometer - Distributer-zone - 8 Valve Opening _DB73

# %%
df2 = df2.rename(columns={"Fibber Optic Thermometer -Distributer-zone -7_DB734,DD134,QC": "DIST_ZONE_7_TEMP", "Fibber Optic Thermometer -Distributer-zone -8_DB737,DD134,QC": "DIST_ZONE_8_TEMP",
                          "Fibber Optic Thermometer -Distributer-zone -6_DB731,DD134,QC": "DIST_ZONE_6_TEMP", "Fiber Optic Thermometer -Distributer-zone -8 Valve Opening _DB73": "DIST_ZONE_8_VALVE_OPENING_TEMP", "ActDrw(Ton)": "Line Draw"})

# %%
df2
# Out:
#      P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  Total Cullet %  \
# 0          29.05            29.1    23.99    82.6       44              30
# 1          30.40            30.4    27.31    89.8       32              30
# 2          27.64            27.6    20.10    72.7       47              30
# 3          26.18            26.2    19.55    74.7       48              30
# 4          25.93            25.9    16.39    63.2       47              30
# ..           ...             ...      ...     ...      ...             ...
# 111        32.37            32.2    27.09    84.2       52              30
# 112        37.28            32.2    27.09    84.2       56              30
# 113        36.63            32.2    27.09    84.2       57              30
# 114        36.02            32.2    27.09    84.2       51              30
# 115        33.85            32.2    27.09    84.2       46              30
#
#      Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
li =list(df2.columns)
li
# Out:
# ['P3_sap_draw',
#  'P3_actual_draw',
#  'P3_pack',
#  'P3_eff',
#  'P3_seed',
#  'Total Cullet %',
#  'Melting cost-Rs/ton/Draw',
#  'Barrier Boosting (kWh)',
#  'Capacitive Boosting (kWh)',
#  'Boosting (kWh)',
#  'Barrier Boosting Per ton (kWh/ton)',
#  'Capacitive Boosting Per ton (kWh/ton)',
#  'FO-Furnace Consumption (MT)',
#  'FO-Furnace Consumption (kg per MT)',
#  'LPG -WE/FHs Consumption(kg)',
#  'Melting Energy -Kcal//Draw of glass',
#  'Bottom Front (oC)',
#  'Throat Riser (oC)',
#  'LPG WE & FH (Kg /Ton/ draw)',
#  'Boosting per ton (kWh/ton draw)',
#  'FO density (Specific Gravity)',
#  'FO consumption (Liters)',
#  'FO L/ton',
#  'Defect Insp Machine%',
#  'Defect Light Inspection%',
#  'Defect Hot End Reject%',
#  'Total Defect%',
#  'Glass CE-kg',
#  'Glass Packing-kg',
#  'FURNACE COMBUSTION AIR FLOW',
#  'FURNACE GAS FLOW',
#  'FURNACE GLASS LEVEL',
#  'FURNACE OIL FLOW',
#  'FURNACE PRESSURE',
#  'LINE P3 ZONE 02 TEMPERATURE',
#  'LINE P3 ZONE 03 TEMPERATURE',
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
clf = RandomForestRegressor(max_depth=20, n_estimators=50)

# %%
li = ["A3Y0118QLQQ110001X", "A3Y0118QLQQ110000X", "F3Y0073QMQQ110002X", "F3Y0060QRPQ110000X", "F3Y0062QRPQ110000X", "F3Z0126QRQQ110000X", "F3W0147ARAQ110000X", "F3W0147QRQQ110000X", "F3X0060QMPQ110002X", "F3Y0070QMPQ110002X", "F3Z0122QMQQ110001X", "F3Z0355QSPQ110000X"]

# %%
df2 = df2[df2["FGCode"].isin(li)]

# %%
y = df2[["Pack to Melt Ratio"]]

# %%
df2
# Out:
#      P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  Total Cullet %  \
# 13         28.60            28.3    25.65    90.6       38              31
# 14         28.70            28.4    25.52    89.9       35              31
# 15         28.67            28.4    25.98    91.6       50              31
# 16         28.71            28.4    23.94    84.3       45              31
# 49         36.36            36.2    16.67    46.1       53              30
# 50         37.16            36.9    20.53    55.7       53              30
# 51         37.13            36.8    23.20    63.0       64              30
# 52         39.64            39.3    26.10    66.3       58              30
# 108        32.45            32.2    26.78    83.3       58              30
# 109        32.54            32.2    26.88    83.4       63              32
# 110        32.49            32.2    27.09    84.2       55              30
#
#      Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
x = df2.drop(["Pack to Melt Ratio", "Name", "Defect Type", "FGCode"], axis=1)

# %%
x
# Out:
#      P3_sap_draw  P3_actual_draw  P3_pack  P3_eff  P3_seed  Total Cullet %  \
# 13         28.60            28.3    25.65    90.6       38              31
# 14         28.70            28.4    25.52    89.9       35              31
# 15         28.67            28.4    25.98    91.6       50              31
# 16         28.71            28.4    23.94    84.3       45              31
# 49         36.36            36.2    16.67    46.1       53              30
# 50         37.16            36.9    20.53    55.7       53              30
# 51         37.13            36.8    23.20    63.0       64              30
# 52         39.64            39.3    26.10    66.3       58              30
# 108        32.45            32.2    26.78    83.3       58              30
# 109        32.54            32.2    26.88    83.4       63              32
# 110        32.49            32.2    27.09    84.2       55              30
#
#      Melting cost-Rs/ton/Draw  Barrier Boosting (kWh)  \
# ...

# %%
y
# Out:
#      Pack to Melt Ratio
# 13             0.906360
# 14             0.898592
# 15             0.914789
# 16             0.842958
# 49             0.460497
# 50             0.556369
# 51             0.630435
# 52             0.664122
# 108            0.831677
# 109            0.834783
# 110            0.841304

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=101)

# %%
X_train.isna().sum()
# Out:
# P3_sap_draw       0
# P3_actual_draw    0
# P3_pack           0
# P3_eff            0
# P3_seed           0
#                  ..
# K2O               0
# TiO2              0
# Draw              0
# Defect Count      0
# Sample Size       0
# Length: 150, dtype: int64

# %%
X_train.countna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-fd591e913b23> in <module>
# ----> 1 X_train.countna()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'countna'

# %%
clf.fit(X_train, y_train)
# Out:
# C:\Users\Rishav\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
from pdpbox import pdp, get_dataset, info_plots

# %%
inter_rf = pdp.pdp_interact(
    model=clf, dataset=df2, model_features=X_train.columns,
    features=["P3_actual_draw", "P3_seed"]
)
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ["P3_actual_draw", "P3_seed"], x_quantile=True, plot_type='contour', plot_pdp=False
)

# %%
inter_rf = pdp.pdp_interact(
    model=clf, dataset=df2, model_features=X_train.columns,
    features=["P3_actual_draw", "Na2O"]
)
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ["P3_actual_draw", "Na2O"], x_quantile=True, plot_type='contour', plot_pdp=False
)

# %%
inter_rf = pdp.pdp_interact(
    model=clf, dataset=df2, model_features=X_train.columns,
    features=["P3_actual_draw", "Total Cullet %"]
)
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ["P3_actual_draw", "Total Cullet %"], x_quantile=True, plot_type='contour', plot_pdp=False
)

# %%
inter_rf = pdp.pdp_interact(
    model=clf, dataset=df2, model_features=X_train.columns,
    features=["P3_actual_draw", "Fe2O3"]
)
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ["P3_actual_draw", "Fe2O3"], x_quantile=True, plot_type='contour', plot_pdp=False
)

# %%
inter_rf = pdp.pdp_interact(
    model=clf, dataset=df2, model_features=X_train.columns,
    features=["P3_actual_draw", "CaO"]
)
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ["P3_actual_draw", "CaO"], x_quantile=True, plot_type='contour', plot_pdp=False
)

# %%
Fibber Optic Thermometer -Distributer-zone -7_DB734,DD134,QC
Fibber Optic Thermometer - Distributer-zone - 8_DB737, DD134, QC
Fibber Optic Thermometer -Distributer-zone -6_DB731,DD134,QC
Fiber Optic Thermometer - Distributer-zone - 8 Valve Opening _DB73

# %%
df3 = df2[(df2["Date"] >= "2021-01-01 16:00:00") & (df2["Date"]<"2021-05-01 03:30:00")]

# %%
df3["DPR Eff"].mean()
# Out:
# 79.87347826086953

# %%
df4 = df2[(df2["Date"] >= "2021-08-05 18:30:00") &
          (df2["Date"] < "2021-11-05 07:00:00")]

# %%
df4["DPR Eff"].mean()
# Out:
# 66.68056603773583

# %%
li = list(df3.columns)
li
# Out:
# ['Date',
#  'DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32',
#  'DCS_160TPD_AIR_PRESSURE_MEASUREMENT_OF_DIST_FH_COMB_BLOWER_HEADER_DFCBPTAI35',
#  'DCS_160TPD_DIST_FH_GAS_FLOW_MEASUREMENT_DFGFTAI25',
#  'DCS_160TPD_DIST_ZONE_1_TEMP_MEASURMENT_DISTPYROZ1AI40',
#  'DCS_160TPD_DIST_ZONE_2_TEMP_MEASURMENT_DISTPYROZ2AI41',
#  'DCS_160TPD_DIST_ZONE_3_TEMP_MEASURMENT_DISTPYROZ3AI42',
#  'DCS_160TPD_DIST_ZONE_4_TEMP_MEASURMENT_DISTPYROZ4AI43',
#  'DCS_160TPD_DIST_ZONE_5_TEMP_MEASURMENT_DISTPYROZ5AI44',
#  'DCS_160TPD_DIST_ZONE_6_TEMP_MEASURMENT_DISTPYROZ6AI45',
#  'DCS_160TPD_DIST_ZONE_7_TEMP_MEASURMENT_DISTPYROZ7AI46',
#  'DCS_160TPD_FH_13_ZONE_1_TEMP_MEASURMENT_FH13PYROZ1AI48',
#  'DCS_160TPD_FH_13_ZONE_2_TEMP_MEASURMENT_FH13PYROZ2AI49',
#  'DCS_160TPD_FH_13_ZONE_3_TEMP_MEASURMENT_FH13PYROZ3AI410',
#  'DCS_160TPD_FH_14_ZONE_1_TEMP_MEASURMENT_FH14PYROZ1AI50',
#  'DCS_160TPD_FH_14_ZONE_2_TEMP_MEASURMENT_FH14PYROZ2AI51',
# ...

# %%
df3 = df3[["DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15", "DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11",
           "DCS_160TPD_MT_BOTTOM_MIDDLE_TEMP_MEASURMENT_MTBOTMTMCTC14", "DCS_160TPD_REGENERATOR_CROWN_RIGHT_SIDE_TEMP_MEASURMENT_REGCRWRTMCTC20", "ProductionOrderNumber"]]

# %%
df3
# Out:
#      DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15  \
# 18                                         1058.743335
# 19                                         1058.743335
# 20                                         1058.596663
# 21                                         1058.596663
# 22                                         1058.083317
# ..                                                 ...
# 105                                        1060.180029
# 106                                        1060.883358
# 107                                        1060.543359
# 108                                        1061.990023
# 109                                        1062.740023
#
#      DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11  \
# 18                                           21.156398
# 19                                           21.156398
# 20                                           20.724059
# 21                                           20.724059
# ...

# %%
df4 = df4[["DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15", "DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11",
           "DCS_160TPD_MT_BOTTOM_MIDDLE_TEMP_MEASURMENT_MTBOTMTMCTC14", "DCS_160TPD_REGENERATOR_CROWN_RIGHT_SIDE_TEMP_MEASURMENT_REGCRWRTMCTC20", "ProductionOrderNumber"]]

# %%
df4
# Out:
#       DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15  \
# 5092                                        1071.613314
# 5094                                        1071.396680
# 5096                                        1070.323348
# 5098                                        1070.648294
# 5100                                        1070.753337
# ...                                                 ...
# 5297                                        1071.493105
# 5299                                        1071.050000
# 5300                                        1071.270965
# 5301                                        1071.276652
# 5302                                        1071.179997
#
#       DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11  \
# 5092                                          30.347815
# 5094                                          29.818849
# 5096                                          29.563012
# ...

# %%
d = pd.DataFrame()

# %%
l_temp = []
l_tempName = []
l_job = []

# %%
l_temp.append(list(df3["DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15"]))    
l_tempName.append(["MT_BOTTOM_RIGHT_SIDE_TEMP"]*len(df3))
# l_temp.append(
    # list(df3["DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11"]))
# l_tempName.append(["GSPC_GAS_TEMP"]*len(df3))
l_temp.append(list(df3["DCS_160TPD_MT_BOTTOM_MIDDLE_TEMP_MEASURMENT_MTBOTMTMCTC14"]))
l_tempName.append(["MT_BOTTOM_MIDDLE_TEMP"]*len(df3))
l_temp.append(
    list(df3["DCS_160TPD_REGENERATOR_CROWN_RIGHT_SIDE_TEMP_MEASURMENT_REGCRWRTMCTC20"]))
l_tempName.append(["REGENERATOR_CROWN_RIGHT_SIDE_TEMP"]*len(df3))
# l_job.append(list((df3["ProductionOrderNumber"])))
l_job.append(list(df3["ProductionOrderNumber"]))
l_job.append(list(df3["ProductionOrderNumber"]))
l_job.append(list(df3["ProductionOrderNumber"]))

# %%
l_temp.append(
    list(df4["DCS_160TPD_MT_BOTTOM_RIGHT_SIDE_TEMP_MEASURMENT_MTBOTRTMCTC15"]))
l_tempName.append(["MT_BOTTOM_RIGHT_SIDE_TEMP"]*len(df4))
# l_temp.append(
#     list(df4["DCS_160TPD_GSPC_GAS_TEMP_MESURMENT_GSPCTTNG1AAI11"]))
# l_tempName.append(["GSPC_GAS_TEMP"]*len(df4))
l_temp.append(list(df4["DCS_160TPD_MT_BOTTOM_MIDDLE_TEMP_MEASURMENT_MTBOTMTMCTC14"]))
l_tempName.append(["MT_BOTTOM_MIDDLE_TEMP"]*len(df4))
l_temp.append(
    list(df4["DCS_160TPD_REGENERATOR_CROWN_RIGHT_SIDE_TEMP_MEASURMENT_REGCRWRTMCTC20"]))
l_tempName.append(["REGENERATOR_CROWN_RIGHT_SIDE_TEMP"]*len(df4))
l_job.append(list(df4["ProductionOrderNumber"]))
l_job.append(list(df4["ProductionOrderNumber"]))
# l_job.append(list(df4["ProductionOrderNumber"]))
l_job.append(list(df4["ProductionOrderNumber"]))

# %%
l_tempName
# Out:
# [['MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
#   'MT_BOTTOM_RIGHT_SIDE_TEMP',
# ...

# %%
from itertools import chain

# %%
flatten_l_temp = list(chain.from_iterable(l_temp))
flatten_l_tempName = list(chain.from_iterable(l_tempName))
flatten_l_jobs = list(chain.from_iterable(l_job))

# %%
len(flatten_l_jobs)
# Out:
# 594

# %%
len(flatten_l_temp)
# Out:
# 594

# %%
len(flatten_l_tempName)
# Out:
# 594

# %%
d["Temperature"]= flatten_l_temp
d["Temperature_Variation"] = flatten_l_tempName
d["Order_Number"] = flatten_l_jobs

# %%
d
# Out:
#      Temperature              Temperature_Variation  Order_Number
# 0    1058.743335          MT_BOTTOM_RIGHT_SIDE_TEMP     1020424.0
# 1    1058.743335          MT_BOTTOM_RIGHT_SIDE_TEMP     1020424.0
# 2    1058.596663          MT_BOTTOM_RIGHT_SIDE_TEMP     1020424.0
# 3    1058.596663          MT_BOTTOM_RIGHT_SIDE_TEMP     1020424.0
# 4    1058.083317          MT_BOTTOM_RIGHT_SIDE_TEMP     1020424.0
# ..           ...                                ...           ...
# 589  1293.282757  REGENERATOR_CROWN_RIGHT_SIDE_TEMP     1023157.0
# 590  1294.276668  REGENERATOR_CROWN_RIGHT_SIDE_TEMP     1023157.0
# 591  1293.419355  REGENERATOR_CROWN_RIGHT_SIDE_TEMP     1023157.0
# 592  1295.373340  REGENERATOR_CROWN_RIGHT_SIDE_TEMP     1023157.0
# 593  1292.899992  REGENERATOR_CROWN_RIGHT_SIDE_TEMP     1023157.0
#
# [594 rows x 3 columns]

# %%
sns.set(style='whitegrid')

# %%
plt.rcParams["figure.figsize"] = (15, 15)

# %%
sns.boxplot(y='Temperature', x='Temperature_Variation', 
                 data=d, 
                 hue='Order_Number')
                 
plt.legend(bbox_to_anchor=(1.02, 0.15), loc='upper left', borderaxespad=0, title = "Order Number")
plt.gcf()

# %%
print(plt.legend)
# Out:
# <module 'matplotlib.legend' from 'C:\\Users\\Rishav\\anaconda3\\lib\\site-packages\\matplotlib\\legend.py'>
