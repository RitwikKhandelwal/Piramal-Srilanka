# %% [markdown]
# # Analysing flat file

# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
seaborn.set(style='whitegrid')

# %%
df = pd.read_csv('flat file 180ML DCSL LW HIP - outlier removed.csv')

# %%
for col in df.columns:
    print(col)
# Out:
# Date
# Adj_eff
# P5_eff
# P5_sap_draw
# P5_actual_draw
# P5_seed
# Total SAP Draw
# Adjusted Draw
# Total Cullet %
# Melting cost-Rs/ton/Draw
# Barrier Boosting (kWh)
# Capacitive Boosting (kWh)
# Boosting (kWh)
# Barrier Boosting Per ton (kWh/ton)
# Capacitive Boosting Per ton (kWh/ton)
# FO-Furnace Consumption (MT)
# FO-Furnace Consumption (kg per MT)
# LPG -WE/FHs Consumption(kg)
# Melting Energy -Kcal//Draw of glass
# Bottom Front (oC)
# Throat Riser (oC)
# LPG WE & FH (Kg /Ton/ draw)
# Boosting per ton (kWh/ton draw)
# FO density (Specific Gravity)
# FO consumption (Liters)
# FO L/ton
# Glass CE-kg
# Glass Packing-kg
# FURNACE COMBUSTION AIR FLOW
# FURNACE GAS FLOW
# FURNACE GLASS LEVEL
# FURNACE OIL FLOW
# FURNACE PRESSURE
# WORKING END ZONE 1 TEMPERATURE
# WORKING END ZONE 2 TEMPERATURE
# WORKING END ZONE 3 TEMPERATURE
# LINE P5 ZONE 1 LEFT BOTTOM TEMPERATURE
# LINE P5 ZONE 1 LEFT MIDDLE TEMPERATURE
# LINE P5 ZONE 1 LEFT TOP TEMPERATURE
# ...

# %% [markdown]
# # Generating histograms

# %%
li = ['CaO','Al2O3','Fe2O3','K2O','MgO','Na2O','SiO2','TiO2','Density (g/cm3)','Total Cullet %','FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE','FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE','FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE','FOREHEART LINE P5 ZONE 2 TEMPERATURE','FOREHEART LINE P5 ZONE 3 TEMPERATURE','P5_seed','FOREHEART LINE P5 ZONE 4 TEMPERATURE','FOREHEART LINE P5 ZONE 5 TEMPERATURE']
dict = {}
for i in range(len(li)):
    dict[i] = li[i]
print(dict)
# Out:
# {0: 'CaO', 1: 'Al2O3', 2: 'Fe2O3', 3: 'K2O', 4: 'MgO', 5: 'Na2O', 6: 'SiO2', 7: 'TiO2', 8: 'Density (g/cm3)', 9: 'Total Cullet %', 10: 'FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE', 11: 'FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE', 12: 'FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE', 13: 'FOREHEART LINE P5 ZONE 2 TEMPERATURE', 14: 'FOREHEART LINE P5 ZONE 3 TEMPERATURE', 15: 'P5_seed', 16: 'FOREHEART LINE P5 ZONE 4 TEMPERATURE', 17: 'FOREHEART LINE P5 ZONE 5 TEMPERATURE'}

# %%
print(dict[0])
arr = df[li[0]].to_numpy()
plt.hist(arr)
a = str(dict[0]).replace('/','_')
plt.savefig(a)
# Out:
# CaO

# %%
print(dict[1])
arr = df[li[1]].to_numpy()
plt.hist(arr)
a = str(dict[1]).replace('/','_')
plt.savefig(a)
# Out:
# Al2O3

# %%
print(dict[2])
arr = df[li[2]].to_numpy()
plt.hist(arr)
a = str(dict[2]).replace('/','_')
plt.savefig(a)
# Out:
# Fe2O3

# %%
print(dict[3])
arr = df[li[3]].to_numpy()
plt.hist(arr)
a = str(dict[3]).replace('/','_')
plt.savefig(a)
# Out:
# K2O

# %%
print(dict[4])
arr = df[li[4]].to_numpy()
plt.hist(arr)
a = str(dict[4]).replace('/','_')
plt.savefig(a)
# Out:
# MgO

# %%
print(dict[5])
arr = df[li[5]].to_numpy()
plt.hist(arr)
a = str(dict[5]).replace('/','_')
plt.savefig(a)
# Out:
# Na2O

# %%
print(dict[6])
arr = df[li[6]].to_numpy()
plt.hist(arr)
a = str(dict[6]).replace('/','_')
plt.savefig(a)
# Out:
# SiO2

# %%
print(dict[7])
arr = df[li[7]].to_numpy()
plt.hist(arr)
a = str(dict[7]).replace('/','_')
plt.savefig(a)
# Out:
# TiO2

# %%
print(dict[8])
arr = df[li[8]].to_numpy()
plt.hist(arr)
a = str(dict[8]).replace('/','_')
plt.savefig(a)
# Out:
# Density (g/cm3)

# %%
print(dict[9])
arr = df[li[9]].to_numpy()
plt.hist(arr)
a = str(dict[9]).replace('/','_')
plt.savefig(a)
# Out:
# Total Cullet %

# %%
print(dict[10])
arr = df[li[10]].to_numpy()
plt.hist(arr)
a = str(dict[10]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE

# %%
print(dict[11])
arr = df[li[11]].to_numpy()
plt.hist(arr)
a = str(dict[11]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE

# %%
print(dict[12])
arr = df[li[12]].to_numpy()
plt.hist(arr)
a = str(dict[12]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE

# %%
print(dict[13])
arr = df[li[13]].to_numpy()
plt.hist(arr)
a = str(dict[13]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 2 TEMPERATURE

# %%
print(dict[14])
arr = df[li[14]].to_numpy()
plt.hist(arr)
a = str(dict[14]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 3 TEMPERATURE

# %%
print(dict[15])
arr = df[li[15]].to_numpy()
plt.hist(arr)
a = str(dict[15]).replace('/','_')
plt.savefig(a)
# Out:
# P5_seed

# %%
print(dict[16])
arr = df[li[16]].to_numpy()
plt.hist(arr)
a = str(dict[16]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 4 TEMPERATURE

# %%
print(dict[17])
arr = df[li[17]].to_numpy()
plt.hist(arr)
a = str(dict[17]).replace('/','_')
plt.savefig(a)
# Out:
# FOREHEART LINE P5 ZONE 5 TEMPERATURE

# %%
var_imp = ['Barrier Boosting (kWh)','Boosting (kWh)','Barrier Boosting Per ton (kWh/ton)','FO density (Specific Gravity)','FO L/ton']
dicti = {}
for i in range(len(var_imp)):
    dicti[i] = var_imp[i]

# %%
print(dicti[0])
arr = df[var_imp[0]].to_numpy()
plt.hist(arr)
plt.savefig(str(dicti[0]))
# Out:
# Barrier Boosting (kWh)

# %%
print(dicti[1])
arr = df[var_imp[1]].to_numpy()
plt.hist(arr)
plt.savefig(str(dicti[1]))
# Out:
# Boosting (kWh)

# %%
print(dicti[2])
arr = df[var_imp[2]].to_numpy()
plt.hist(arr)
a = str(dicti[2]).replace('/','_')
plt.savefig(a)
# Out:
# Barrier Boosting Per ton (kWh/ton)

# %%
print(dicti[3])
arr = df[var_imp[3]].to_numpy()
plt.hist(arr)
a = str(dicti[3]).replace('/','_')
plt.savefig(a)
# Out:
# FO density (Specific Gravity)

# %%
print(dicti[4])
arr = df[var_imp[4]].to_numpy()
plt.hist(arr)

a = str(dicti[4]).replace('/','_')
plt.savefig(a)
# Out:
# FO L/ton

# %% [markdown]
# ## Product 2

# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
seaborn.set(style='whitegrid')

# %%
df2 = pd.read_csv('product 2/flatfile_prod2.csv')

# %%
df2= df2.loc[:31,:]
df2
# Out:
#          Date  P5_eff    Adj_eff  P5_sap_draw  P5_actual_draw  P5_seed  \
# 0   20-Dec-21    89.8  85.302594        57.01            57.0      9.0
# 1   21-Dec-21    93.0  83.835616        56.72            56.7      6.0
# 2   22-Dec-21    93.1  85.490896        56.74            56.7      9.0
# 3   23-Dec-21    93.1  83.174603        56.68            56.7     12.0
# 4   24-Dec-21    93.0  87.867984        56.61            56.6     17.0
# 5   25-Dec-21    91.3  90.061509        56.89            56.9     16.0
# 6   26-Dec-21    92.5  91.834300        57.10            57.1      9.0
# 7   27-Dec-21    92.3  89.601158        56.75            56.8     14.0
# 8   28-Dec-21    93.3  92.756184        56.90            56.9      3.0
# 9   29-Dec-21    93.6  87.787206        57.06            57.1     10.0
# 10  30-Dec-21    92.1  79.283419        56.94            56.9     18.0
# 11  31-Dec-21    90.4  84.698661        57.03            57.0     13.0
# ...

# %%
# new_vars_full_dataset = ['FLV_combustion','SPV_combustion','PVV_oil','SPRV_combustion','QVV_oil']
# dict2 = {}
# for i in range(len(new_vars_full_dataset)):
#     dict2[i] = new_vars_full_dataset[i]
# print(dict2)
# Out:
# {0: 'FLV_combustion', 1: 'SPV_combustion', 2: 'PVV_oil', 3: 'SPRV_combustion', 4: 'QVV_oil'}

# %%
# i = 4
# print(dict2[i])
# arr = df2[new_vars_full_dataset[i]].to_numpy()

# font = {'size': 5}
  
# # using rc function
# plt.rc('font', **font)

# plt.hist(arr)

# a = str(dict2[i]).replace('/','_')
# b = 'product 2/plots/hist/'
# plt.savefig(b+a)
# Out:
# QVV_oil

# %%
li2 = ['CaO','Al2O3','Fe2O3','K2O','MgO','Na2O','SiO2','TiO2','Density (g/cm3)','Total Cullet %','FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE','FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE','FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE','FOREHEART LINE P5 ZONE 2 TEMPERATURE','FOREHEART LINE P5 ZONE 3 TEMPERATURE','P5_seed','FOREHEART LINE P5 ZONE 4 TEMPERATURE','FOREHEART LINE P5 ZONE 5 TEMPERATURE','Capacitive Boosting (kWh)','LINE P5 ZONE 1 LEFT TOP TEMPERATURE','CAPACITOR BOOSTING TRANSFORMER KWH prvmonth','CAPACITOR BOOSTING TRANSFORMER L3 Total Current','LINE P5 ZONE 1 MIDDLE BOTTOM TEMPERATURE']
dict2 = {}
for i in range(len(li2)):
    dict2[i] = li2[i]
print(dict2)
# Out:
# {0: 'CaO', 1: 'Al2O3', 2: 'Fe2O3', 3: 'K2O', 4: 'MgO', 5: 'Na2O', 6: 'SiO2', 7: 'TiO2', 8: 'Density (g/cm3)', 9: 'Total Cullet %', 10: 'FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE', 11: 'FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE', 12: 'FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE', 13: 'FOREHEART LINE P5 ZONE 2 TEMPERATURE', 14: 'FOREHEART LINE P5 ZONE 3 TEMPERATURE', 15: 'P5_seed', 16: 'FOREHEART LINE P5 ZONE 4 TEMPERATURE', 17: 'FOREHEART LINE P5 ZONE 5 TEMPERATURE', 18: 'Capacitive Boosting (kWh)', 19: 'LINE P5 ZONE 1 LEFT TOP TEMPERATURE', 20: 'CAPACITOR BOOSTING TRANSFORMER KWH prvmonth', 21: 'CAPACITOR BOOSTING TRANSFORMER L3 Total Current', 22: 'LINE P5 ZONE 1 MIDDLE BOTTOM TEMPERATURE'}

# %%
for i in range(len(li2)):
    print(dict2[i])
    arr = df2[li2[i]].to_numpy()
    plt.hist(arr)
    a = str(dict2[i]).replace('/','_')
    b = 'product 2/plots/hist/'
    plt.savefig(b+a)
# Out:
# CaO
# Al2O3
# Fe2O3
# K2O
# MgO
# Na2O
# SiO2
# TiO2
# Density (g/cm3)
# Total Cullet %
# FOREHEART LINE P5 ZONE 1 TOP TEMPERATURE
# FOREHEART LINE P5 ZONE 1 MIDDLE TEMPERATURE
# FOREHEART LINE P5 ZONE 1 BOTTOM TEMPERATURE
# FOREHEART LINE P5 ZONE 2 TEMPERATURE
# FOREHEART LINE P5 ZONE 3 TEMPERATURE
# P5_seed
# FOREHEART LINE P5 ZONE 4 TEMPERATURE
# FOREHEART LINE P5 ZONE 5 TEMPERATURE
# Capacitive Boosting (kWh)
# LINE P5 ZONE 1 LEFT TOP TEMPERATURE
# CAPACITOR BOOSTING TRANSFORMER KWH prvmonth
# CAPACITOR BOOSTING TRANSFORMER L3 Total Current
# LINE P5 ZONE 1 MIDDLE BOTTOM TEMPERATURE

# %%
#Manually change iterator
i = 20
print(dict2[i])
arr = df2[li2[i]].to_numpy()

font = {'size': 5}
  
# using rc function
plt.rc('font', **font)

plt.hist(arr)

a = str(dict2[i]).replace('/','_')
b = 'product 2/plots/hist/'
plt.savefig(b+a)
# Out:
# CAPACITOR BOOSTING TRANSFORMER KWH prvmonth
